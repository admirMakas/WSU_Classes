# %%
# %matplotlib inline
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import sympy as sm
sm.init_printing(use_latex='mathjax')
from IPython.display import display
from IPython.display import Image
import scipy.linalg as la
import control as ctrl

# %% [markdown]
# #### Load . mat file 'mckiddat.mat'

# %%
data = sio.loadmat('mckiddat2.mat')

# %% [markdown]
# #### Show contents of the .mat file

# %%
sio.whosmat('mckiddat2.mat')
# Out:
# [('Freq', (401, 1), 'double'),
#  ('IRF_11', (802, 1), 'double'),
#  ('IRF_12', (802, 1), 'double'),
#  ('IRF_13', (802, 1), 'double'),
#  ('Recep', (401, 3), 'double'),
#  ('t', (802, 1), 'double')]

# %% [markdown]
# #### Define data structures

# %%
Freq = data['Freq'];
Recep = data['Recep'];
t = data['t'];
IRF_11 = data['IRF_11'];
IRF_12 = data['IRF_12'];
IRF_13 = data['IRF_13'];

# %% [markdown]
# ### Plot the given data:

# %% [markdown]
# #### Plot for $H_{11}$.

# %%
#Plot of H11 FRF
fig = plt.figure()
plt.plot(Freq, 20*np.log10(abs(Recep[:,0])), color='r', linewidth=2.0)
fig.suptitle('$H_{11}$ FRF', fontsize = 14)
plt.xlabel('Freq')
plt.ylabel('Amp. dB')
plt.axis([0, 0.42, -40, 40])
plt.grid()
plt.show()

#next plot phase diagram
phase_11 = sp.unwrap(sp.angle(Recep[:,0]))*(180/sp.pi)
fig = plt.figure()
plt.plot(Freq, phase_11, color='b', linewidth=2.0)
fig.suptitle('$H_{11}$ Phase', fontsize = 14)
plt.xlabel('Freq')
plt.ylabel('Angle')

plt.grid()
plt.show()

# %% [markdown]
# #### Plot for $H_{12}$.

# %%
#Plot of H12 FRF
fig = plt.figure()
plt.plot(Freq, 20*np.log10(abs(Recep[:,1])), color='r', linewidth=2.0)
fig.suptitle('$H_{12}$ FRF', fontsize = 14)
plt.xlabel('Freq')
plt.ylabel('Amp. dB')
plt.axis([0, 0.42, -40, 40])
plt.grid()
plt.show()

#next plot phase diagram
phase_12 = sp.unwrap(sp.angle(Recep[:,1]))*(180/sp.pi)
fig = plt.figure()
plt.plot(Freq, phase_12, color='b', linewidth=2.0)
fig.suptitle('$H_{12}$ Phase', fontsize = 14)
plt.xlabel('Freq')
plt.ylabel('Angle')

plt.grid()
plt.show()

# %% [markdown]
# #### Plot for $H_{13}$.

# %%
#Plot of H13 FRF
fig = plt.figure()
plt.plot(Freq, 20*np.log10(abs(Recep[:,2])), color='r', linewidth=2.0)
fig.suptitle('$H_{13}$ FRF', fontsize = 14)
plt.xlabel('Freq')
plt.ylabel('Amp. dB')
plt.axis([0, 0.42, -40, 40])
plt.grid()
plt.show()

#next plot phase diagram
phase_13 = sp.unwrap(sp.angle(Recep[:,2]))*(180/sp.pi)
fig = plt.figure()
plt.plot(Freq, phase_13, color='b', linewidth=2.0)
fig.suptitle('$H_{13}$ Phase', fontsize = 14)
plt.xlabel('Freq')
plt.ylabel('Angle')

plt.grid()
plt.show()

# %% [markdown]
# #### From the FRF graphs above use quadrature peak picking method to determine following:
#
# - Natural Frequencies
# - Damping ratios
# - Mode shapes

# %% [markdown]
# From the FRF plots above the following 3 natural frequencies are determined:
#
# - **$\omega_1$ = 0.103**
# - **$\omega_2$ = 0.196**
# - **$\omega_3$ = 0.325**

# %% [markdown]
# ### Calculation of $\zeta$ :

# %% [markdown]
# **$\zeta_1$ is calculated from the figure below. A 3 dB drop was used to get data to be used in following equation:**
#
# - $\zeta = \frac{f_2-f_1}{2f_p}$
# - where $f_p$ = 0.103, $f_2$ = 0.1033, and $f_1$ = 0.1027
# - **$\zeta$ = 0.0029**

# %%
Image("Peak1_Meas.png")

# %% [markdown]
# **$\zeta_2$ is calculated from the figure below. A 3 dB drop was used to get data to be used in following equation:**
#
# - $\zeta = \frac{f_2-f_1}{2f_p}$
# - where $f_p$ = 0.196, $f_2$ = 0.1968, and $f_1$ = 0.1955
# - **$\zeta$ = 0.0033**

# %%
Image("Peak2_Meas.png")

# %% [markdown]
# **$\zeta_3$ is calculated from the figure below. A 3 dB drop was used to get data to be used in following equation:**
#
# - $\zeta = \frac{f_2-f_1}{2f_p}$
# - where $f_p$ = 0.325, $f_2$ = 0.3276, and $f_1$ = 0.3223
# - **$\zeta$ = 0.0082**

# %%
Image("Peak3_Meas.png")

# %% [markdown]
# ## Plot time data obtained from the FRF's
#
# Time data was obtained from vibrations toolbox function 'IRF'

# %%
fig = plt.figure()
plt.plot(t, IRF_11, color='r', linewidth=1.0)
#
fig.suptitle('Time History $H_{11}$', fontsize = 14)
plt.xlabel('Time, sec')
plt.ylabel('Amp.')
plt.axis([0, 1000, -0.6, 0.6])
#
plt.grid()

# %%
fig = plt.figure()
plt.plot(t, IRF_12, color='r', linewidth=1.0)
#
fig.suptitle('Time History $H_{12}$', fontsize = 14)
plt.xlabel('Time, sec')
plt.ylabel('Amp.')
plt.axis([0, 1000, -0.4, 0.4])
#
plt.grid()

# %%
fig = plt.figure()
plt.plot(t, IRF_13, color='r', linewidth=1.0)
#
fig.suptitle('Time History $H_{13}$', fontsize = 14)
plt.xlabel('Time, sec')
plt.ylabel('Amp.')
plt.axis([0, 1000, -0.3, 0.3])
#
plt.grid()

# %% [markdown]
# **Define dt for later use:**

# %%
dt=t[1]
dt=dt[0]
dt
# Out:
# 1.26262626263

# %% [markdown]
# ## Start with defining all the Markov paramaters available:
#
# This will yiels a 1 by 3 matrix for each instance.

# %%
M=sp.array([IRF_11[:,0], IRF_12[:,0], IRF_13[:,0]]).T
display(M)
# Out:
# array([[  7.12525864e-02,  -8.97410927e-02,  -2.16518762e-04],
#        [  5.18989926e-01,  -5.77539023e-03,  -5.08048481e-02],
#        [  2.46427900e-01,   3.91599043e-01,   5.87326855e-03],
#        ...,
#        [  8.57423581e-03,   1.35764096e-02,   4.55806346e-04],
#        [ -2.69818797e-02,  -3.06581263e-02,  -3.86196876e-03],
#        [ -7.88591807e-02,  -3.05409593e-02,  -2.28704707e-02]])

# %%
display(M[0,:])
display(M[1,:])
display(M[2,:])
display(M[3,:])
display(M[4,:])
display(M[5,:])
display(M[6,:])
# Out:
# array([ 0.07125259, -0.08974109, -0.00021652])
# array([ 0.51898993, -0.00577539, -0.05080485])
# array([ 0.2464279 ,  0.39159904,  0.00587327])
# array([ 0.10088929,  0.16747772,  0.3448987 ])
# array([-0.08586504,  0.11604616, -0.03862483])
# array([ 0.0364404 , -0.29674266, -0.2248716 ])
# array([-0.23486193, -0.34190374, -0.09653892])

# %%
M.shape
# Out:
# (802, 3)

# %% [markdown]
# **Try and define $H(0)$ matrix from the defined Markov paramaters:**

# %%
# Construct H0

#define how many rows you will have (a index)
a=601
#define how many columns you will have (b index)
b=150

#Indeces a and be above do not really give size of
#final matrix. That will be the following
row_i=a-1
column_i=b
display('rows', row_i)
display('columns', column_i)

#get 1st column
H0=M[1:a, :3]
#display(H0)

for i in range(1,b):
    k=1+i
    Hi=M[k:a+i, :3]
    H0=sp.concatenate((H0, Hi), axis=1)
    
display(H0)

display('H0 shape ', H0.shape)

#display(i)
#display(k)
display('Last M row used ', (a+i))

index1=H0.shape[0]
index2=H0.shape[1]
display('indices')
display(index1, index2)
# Out:
# 'rows'
# 600
# 'columns'
# 150
# array([[ 0.51898993, -0.00577539, -0.05080485, ...,  0.11631042,
#          0.2406303 ,  0.1463049 ],
#        [ 0.2464279 ,  0.39159904,  0.00587327, ...,  0.15335219,
#          0.17025698,  0.09830961],
#        [ 0.10088929,  0.16747772,  0.3448987 , ...,  0.14565854,
#         -0.01167504, -0.06156685],
#        ...,
#        [-0.06889261, -0.07032849, -0.03452533, ..., -0.06785876,
#         -0.0468169 , -0.01600497],
#        [-0.08405654, -0.06531955, -0.02577849, ..., -0.03054849,
#         -0.02335287, -0.00846064],
#        [-0.04501445, -0.02154041, -0.00215497, ...,  0.02637802,
#          0.01428405,  0.00267302]])
# 'H0 shape '
# (600, 450)
# 'Last M row used '
# 750
# 'indices'
# 600
# 450

# %%
# Construct H1

#Used same a and b from H0 definition

#Indeces a and be above do not really give size of
#final matrix. That will be the following
row_i=a-1
column_i=b
display('rows', row_i)
display('columns', column_i)

#get 1st column for H1, which will be starting at M(2)
H1=M[2:a+1, :3]

for j in range(1,b):
    k=2+j
    Hj=M[k:a+j+1, :3]
    H1=sp.concatenate((H1, Hj), axis=1)
    
display(H1)

#H1=H1[:index, :index]
display(H1.shape)
# Out:
# 'rows'
# 600
# 'columns'
# 150
# array([[ 0.2464279 ,  0.39159904,  0.00587327, ...,  0.15335219,
#          0.17025698,  0.09830961],
#        [ 0.10088929,  0.16747772,  0.3448987 , ...,  0.14565854,
#         -0.01167504, -0.06156685],
#        [-0.08586504,  0.11604616, -0.03862483, ..., -0.09380027,
#         -0.13378987, -0.08399936],
#        ...,
#        [-0.08405654, -0.06531955, -0.02577849, ..., -0.03054849,
#         -0.02335287, -0.00846064],
#        [-0.04501445, -0.02154041, -0.00215497, ...,  0.02637802,
#          0.01428405,  0.00267302],
#        [ 0.03750648,  0.02929697,  0.01147744, ...,  0.0600718 ,
#          0.04532692,  0.01743855]])
# (600, 450)

# %% [markdown]
# **Perform SVD on the H0 matrix to get following matrices:**
#
# - U, $V^T$, and $\Sigma$

# %%
U, Sig, Vt = la.svd(H0)
display('raw Vt ', Vt.shape)
display('raw U ', U.shape)
V=Vt.T

if index2<index1:
    display('if statement done')
    V=V[:, :index2]
    display('V size ', V.shape)
    U=U[:, :index2]
    display('U size ', U.shape)
else:
    display('else statement')
    V=V[:, :index1]
    display(V.shape)
    U=U[:index1, :]
    display(U.shape)
# Out:
# 'raw Vt '
# (450, 450)
# 'raw U '
# (600, 600)
# 'if statement done'
# 'V size '
# (450, 450)
# 'U size '
# (600, 450)

# %%
#Sig

# %%
fig = plt.figure()
plt.plot(Sig, color='r', linewidth=2.0)
#
fig.suptitle('Diagonal Values from $\Sigma$', fontsize = 14)
plt.xlabel('Index')
plt.ylabel('Amp.')
plt.axis([0, 20, -0.25, 40])
#
plt.grid()

# %% [markdown]
# **Based on plot above for diagonal values $\Sigma$ there are only 6 significant values. Therefore, matrices A, B, C, D will be resized to following dimensions:**
#
# - A: 6 by 6
# - B: 6 by 1
# - C: 3 by 6
# - D: 3 by 1

# %% [markdown]
# **Put all values of Sig on a diagonal:**

# %%
SigD = sp.diag(Sig)
display(SigD.shape)
# Out:
# (450, 450)

# %% [markdown]
# **Next Construct the H1 matrix:**

# %% [markdown]
# ### Calculation of state matix A:

# %% [markdown]
# **Calculate discrete state matrix $A_d$:**

# %%
A_d = la.inv(sp.sqrt(SigD))@U.T@H1@V@la.inv(sp.sqrt(SigD))
display(A_d)
display(A_d.shape)
# Out:
# array([[  6.91359529e-01,  -7.17539808e-01,  -2.45527966e-03, ...,
#          -1.07704355e-08,   1.99229287e-08,   6.42221107e-09],
#        [  7.22209143e-01,   6.90444196e-01,  -1.01305385e-02, ...,
#          -2.40026848e-08,  -2.78921001e-09,   4.49554775e-09],
#        [ -2.48546789e-03,   4.45442750e-03,   3.40965937e-02, ...,
#           1.00972833e-08,  -5.87726396e-09,   1.96680214e-09],
#        ...,
#        [  1.34900378e-08,  -7.86054943e-09,  -2.56227803e-09, ...,
#           6.57895729e-02,  -1.07042829e-02,   1.27250865e-01],
#        [  2.96807008e-09,   1.37663395e-09,  -3.20360880e-09, ...,
#           1.11436505e-01,   8.21727924e-02,   8.13093513e-02],
#        [  5.79403540e-09,  -6.11140914e-09,  -4.37336032e-09, ...,
#           9.40508862e-02,   1.70521790e-01,   9.74942310e-02]])
# (450, 450)

# %%
#lam_d, vec = la.eig(A_d)
#print(lam_d)
#print(vec)

# %%
#lam = sp.log(lam_d)/dt
#lam

# %%
# These are the continuous time eigenvalues
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[0])))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[1])))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[2])))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[3])))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[4])))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[5])))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[6])))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[7])))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[8])))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[9])))

# %% [markdown]
# **Because $\Sigma$ matrix has only 6 values that are significant the $A_d$ matrix is truncated to a 6 by 6 in order to proceed with the calculation of continuous state space matrix A.**

# %%
A_d=A_d[:6,:6]
display(A_d)
display(A_d.shape)
# Out:
# array([[  6.91359529e-01,  -7.17539808e-01,  -2.45527966e-03,
#          -2.22575102e-03,  -1.80778017e-03,  -8.34885308e-04],
#        [  7.22209143e-01,   6.90444196e-01,  -1.01305385e-02,
#           2.03363866e-04,  -6.58050622e-03,  -3.47702226e-03],
#        [ -2.48546789e-03,   4.45442750e-03,   3.40965937e-02,
#          -9.93156914e-01,  -5.13199662e-04,   1.40738948e-03],
#        [  2.61168239e-03,   1.86003471e-03,   9.95610773e-01,
#           3.34409865e-02,  -1.58767072e-02,  -8.18464149e-03],
#        [ -6.97571716e-04,   8.69226133e-04,  -2.26485389e-03,
#           6.98188032e-03,  -8.10572171e-01,   5.51636870e-01],
#        [ -2.19462739e-04,  -7.69848937e-04,  -2.77484891e-03,
#          -3.68415162e-03,  -5.51695286e-01,  -8.09803008e-01]])
# (6, 6)

# %%
lam_d, vec = la.eig(A_d)
print(lam_d)
#print(vec)
# Out:
# [ 0.69090238+0.71988591j  0.69090238-0.71988591j  0.03376615+0.99441615j
#   0.03376615-0.99441615j -0.81018547+0.55170092j -0.81018547-0.55170092j]

# %%
lam = sp.log(lam_d)/dt
lam
# Out:
# array([-0.00175348+0.63830407j, -0.00175348-0.63830407j,
#        -0.00397848+1.21718806j, -0.00397848-1.21718806j,
#        -0.01584620+2.01465977j, -0.01584620-2.01465977j])

# %%
# These are the continuous time eigenvalues
print('The undamped natural frequency #1 is {} Hz.'.format(abs(lam[0])/(2*sp.pi)))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[1])))
print('The undamped natural frequency #2 is {} Hz.'.format(abs(lam[2])/(2*sp.pi)))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[3])))
print('The undamped natural frequency #3 is {} Hz.'.format(abs(lam[4])/(2*sp.pi)))
#print('The undamped natural frequency is {} rad/sec.'.format(abs(lam[5])))
print('The damping ratio for frequency #1 is {}.'.format(-sp.real(lam[0])/abs(lam[0])))
print('The damping ratio for frequency #2 is {}.'.format(-sp.real(lam[2])/abs(lam[2])))
print('The damping ratio for frequency #3 is {}.'.format(-sp.real(lam[4])/abs(lam[4])))
# Out:
# The undamped natural frequency #1 is 0.10158963194541061 Hz.
# The undamped natural frequency #2 is 0.19372253125390357 Hz.
# The undamped natural frequency #3 is 0.3206529794588755 Hz.
# The damping ratio for frequency #1 is 0.0027470757245525654.
# The damping ratio for frequency #2 is 0.003268566378162904.
# The damping ratio for frequency #3 is 0.007865203447648848.

# %% [markdown]
# **Calculate continuous state matrix A:**

# %%
A = la.logm(A_d)/dt
#display(A)
display(A.shape)
# Out:
# (6, 6)

# %% [markdown]
# ### Calculation of matrix B:

# %% [markdown]
# **Calculate discrete matrix $B_d$:**

# %%
B_d = sp.sqrt(SigD)@V.T[:,0].T.reshape((index2,1))
#B_d = sp.sqrt(SigD)@V.T[:,0]
#print(B_d)
display(B_d.shape)
# Out:
# (450, 1)

# %% [markdown]
# **Reshape matrix B to be a 6 by 1 matrix.**

# %%
B_d=B_d[:6,:]
display(B_d)
display(B_d.shape)
# Out:
# array([[-0.54854093],
#        [ 0.22383058],
#        [-0.48248019],
#        [-0.01206925],
#        [-0.22186319],
#        [ 0.1146622 ]])
# (6, 1)

# %% [markdown]
# **Calculate continuous matrix B:**

# %%
B = la.solve((A_d - sp.eye(6)), A) @ B_d
print(B)
display(B.shape)
# Out:
# [[-0.34079236 +6.20718355e-17j]
#  [ 0.34155888 -6.05830009e-17j]
#  [-0.31438834 -2.39654562e-17j]
#  [ 0.28618128 +2.44800135e-17j]
#  [-0.18734953 +4.32597811e-17j]
#  [-0.19242737 -3.98175067e-17j]]
# (6, 1)

# %% [markdown]
# ### Calculation of matrix C:

# %%
C = (U @ sp.sqrt(SigD))[:3,:]
#C=sp.array([C])
print(C)
display(C.shape)
# Out:
# [[ -4.97332460e-01  -2.71893363e-01  -5.35133651e-01 ...,   1.48829126e-15
#     4.83516186e-16   4.72190398e-16]
#  [ -5.38674914e-01   1.66669167e-01  -3.91947201e-02 ...,   1.73418482e-13
#     5.25784531e-14   5.66957148e-14]
#  [ -2.50844402e-01   5.02781164e-01   5.25329474e-01 ...,   4.63152846e-12
#     1.31446917e-12   1.55136178e-12]]
# (3, 450)

# %% [markdown]
# **Reshape matrix C to be a 3 by 6.**

# %%
C=C[:,:6]
display(C)
display(C.shape)
# Out:
# array([[-0.49733246, -0.27189336, -0.53513365, -0.02649187, -0.4019367 ,
#         -0.21000638],
#        [-0.53867491,  0.16666917, -0.03919472,  0.53020367,  0.44651544,
#         -0.05374016],
#        [-0.2508444 ,  0.50278116,  0.52532947,  0.06097851, -0.34142776,
#          0.28653074]])
# (3, 6)

# %% [markdown]
# ### Calculation of matrix D:

# %%
D=M[:1,:3]
D=D.T
display(D)
display(D.shape)
# Out:
# array([[ 0.07125259],
#        [-0.08974109],
#        [-0.00021652]])
# (3, 1)

# %% [markdown]
# ### Construct the state space system from derived matrices

# %%
sys = ctrl.ss(A, B, C, D)
#sys

# %% [markdown]
# ### Plot Identified Ho-Kalman System vs. Lab Data

# %%
def ssfrf(sys, omega_low, omega_high, in_index, out_index):
        A, B, C, D = ctrl.ssdata(sys)
        sa = A.shape[0]
        omega = sp.linspace(omega_low, omega_high,1000)
        H = omega* 1j
        i = 0
        for i in sp.arange(len(omega)):
            w = omega[i]
            H[i] = (C@la.solve(w*1j*sp.eye(sa)-A,B)+D)[out_index,in_index]
        return omega, H

# %%
w, Hx1 = ssfrf(sys, 0, 3, 0, 0)

# %%
#Plot of H11 FRF
fig = plt.figure()
plt.plot(w/(2*sp.pi), 20*np.log10(abs(Hx1)),'b--', linewidth=2.0, label='System')
plt.plot(Freq, 20*np.log10(abs(Recep[:,0])),'r', linewidth=2.0, label='Exp data')
plt.legend(loc='upper right', shadow=True)
fig.suptitle('$H_{11}$ FRF Est.', fontsize = 14)
plt.xlabel('Freq Hz')
plt.ylabel('Amp. dB')
plt.axis([0, .5, -40, 40])
plt.grid()
plt.show()

#next plot phase diagram
sysP_11 = sp.unwrap(sp.angle(Hx1))*(180/sp.pi)
fig = plt.figure()
plt.plot(w/(2*sp.pi), sysP_11, 'b--', linewidth=2.0, label='System')
plt.plot(Freq, phase_11, 'r', linewidth=2.0, label='Exp data')
plt.legend(loc='upper right', shadow=True)
fig.suptitle('$H_{11}$ Phase Est', fontsize = 14)
plt.xlabel('Freq')
plt.ylabel('Angle')

plt.grid()
plt.show()

# %%
w, Hx2 = ssfrf(sys, 0, 3, 0, 1)

# %%
#Plot of H12 FRF
fig = plt.figure()
plt.plot(w/(2*sp.pi), 20*np.log10(abs(Hx2)),'b--', linewidth=2.0, label='System')
plt.plot(Freq, 20*np.log10(abs(Recep[:,1])), 'r', linewidth=2.0,  label='Exp data')
plt.legend(loc='upper right', shadow=True)
fig.suptitle('$H_{12}$ FRF Est.', fontsize = 14)
plt.xlabel('Freq Hz')
plt.ylabel('Amp. dB')
plt.axis([0, .5, -40, 40])
plt.grid()
plt.show()

#next plot phase diagram
sysP_12 = sp.unwrap(sp.angle(Hx2))*(180/sp.pi)
fig = plt.figure()
plt.plot(w/(2*sp.pi), sysP_12, 'b--', linewidth=2.0, label='System')
plt.plot(Freq, phase_12, 'r', linewidth=2.0, label='Exp data')
plt.legend(loc='upper right', shadow=True)
fig.suptitle('$H_{12}$ Phase Est', fontsize = 14)
plt.xlabel('Freq')
plt.ylabel('Angle')

plt.grid()
plt.show()

# %%
w, Hx3 = ssfrf(sys, 0, 3, 0, 2)

# %%
#Plot of H13 FRF
fig = plt.figure()
plt.plot(w/(2*sp.pi), 20*np.log10(abs(Hx3)), 'b--', linewidth=2.0, label='System')
plt.plot(Freq, 20*np.log10(abs(Recep[:,2])), 'r', linewidth=2.0, label='Exp data')
plt.legend(loc='upper right', shadow=True)
fig.suptitle('$H_{12}$ FRF Est.', fontsize = 14)
plt.xlabel('Freq Hz')
plt.ylabel('Amp. dB')
plt.axis([0, .5, -40, 40])
plt.grid()
plt.show()

#next plot phase diagram
sysP_13 = sp.unwrap(sp.angle(Hx3))*(180/sp.pi)
fig = plt.figure()
plt.plot(w/(2*sp.pi), sysP_13, 'b--', linewidth=2.0, label='System')
plt.plot(Freq, phase_13, 'r', linewidth=2.0, label='Exp data')
plt.legend(loc='upper right', shadow=True)
fig.suptitle('$H_{13}$ Phase Est', fontsize = 14)
plt.xlabel('Freq')
plt.ylabel('Angle')

plt.grid()
plt.show()
