# %%
from IPython.display import Image

# %% [markdown]
# ### Admir Makas

# %% [markdown]
# ### Random Data Analysis
# ### Vibrations Lab # 5

# %% [markdown]
# ### Introduction
#
# After sine sweep data was collected another set of data was gathered using random input from the shaker system. Random data was then used to generate an FRF for the channel 2 and 4 responses. The constructed FRFs were then compared to the FRFs generated from the sine sweep data.

# %% [markdown]
# ### Time Data
#
# Below are time history plots for channels 2 thru 4. Looking at the responses they all appear to be random in nature.

# %%
Image("Time_Plot_Ch2.png")

# %%
Image("Time_Plot_Ch3.png")

# %%
Image("Time_Plot_Ch4.png")

# %% [markdown]
# ### Time Data in Frequency Domain

# %% [markdown]
# Next set of plots show channels 2 thru 4 in frequency domain. Looking at the frequency plot for channel 3 it can be seen that the shaker is exciting a broad range of frequencies.
#
# As a result accelereometers for channels 2 and 4 show spikes in the response in the neighborhood of the natural frequencies of the wing. The wing response is analogous to hammer excitation.

# %%
Image("Freq_Plot_Ch2.png")

# %%
Image("Freq_Plot_Ch3.png")

# %%
Image("Freq_Plot_Ch4.png")

# %% [markdown]
# ### FRF Estimations

# %% [markdown]
# In the next step FRFs were generated for channels 2 and 4 using the same frequecy points that were used for the sine sweep FRFs. Plots below compare random data FRF results to sine sweep results.

# %%
Image("FRF_Phase_Chan2.png")

# %%
Image("FRF_Phase_Chan4.png")

# %% [markdown]
# The FRF amplitudes match between random and sine sweep results but they have a tendency to diverge in the other locations. It is probably not wise to use the random data in this manner. However, it can be used as another way to identify the natural modes of the system.

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
